# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.offline as py
import plotly.graph_objs as go

import folium as fn

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-c14f9806-d730-4005-9760-546224600511" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c14f9806-d730-4005-9760-546224600511">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Zomato.xlsx to Zomato.xlsx
# User uploaded file "Zomato.xlsx" with length 83698020 bytes

# %%
import io

# %%
df = pd.read_excel('Zomato.xlsx')

# %%
df
# Out:
#                                                      url  ... Unnamed: 4159
# 0      https://www.zomato.com/bangalore/jalsa-banasha...  ...           NaN
# 1      https://www.zomato.com/bangalore/spice-elephan...  ...           NaN
# 2      https://www.zomato.com/SanchurroBangalore?cont...  ...           NaN
# 3      https://www.zomato.com/bangalore/addhuri-udupi...  ...           NaN
# 4      https://www.zomato.com/bangalore/grand-village...  ...           NaN
# ...                                                  ...  ...           ...
# 60768  https://www.zomato.com/bangalore/best-brews-fo...  ...           NaN
# 60769  https://www.zomato.com/bangalore/vinod-bar-and...  ...           NaN
# 60770  https://www.zomato.com/bangalore/plunge-sherat...  ...           NaN
# 60771  https://www.zomato.com/bangalore/chime-sherato...  ...           NaN
# 60772  https://www.zomato.com/bangalore/the-nest-the-...  ...           NaN
#
# [60773 rows x 4160 columns]

# %%
df.shape
# Out:
# (60773, 4160)

# %%
#Deleting unwanted column
data = df.drop(df.columns[17:],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60773 entries, 0 to 60772
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          56206 non-null  object
#  1   address                      56235 non-null  object
#  2   name                         56236 non-null  object
#  3   online_order                 56234 non-null  object
#  4   book_table                   56194 non-null  object
#  5   rate                         48414 non-null  object
#  6   votes                        56174 non-null  object
#  7   phone                        54955 non-null  object
#  8   location                     56128 non-null  object
#  9   rest_type                    55914 non-null  object
#  10  dish_liked                   28049 non-null  object
#  11  cuisines                     56049 non-null  object
#  12  approx_cost(for two people)  55745 non-null  object
#  13  reviews_list                 56063 non-null  object
#  14  menu_item                    51684 non-null  object
#  15  listed_in(type)              51655 non-null  object
#  16  listed_in(city)              51626 non-null  object
# dtypes: object(17)
# memory usage: 7.9+ MB

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
# Again deleting unwanted column
#zomato = df.drop(['url','dish_liked','phone'],axis=1)

# %%
#zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
#checking data type
df.dtypes
# Out:
# url             object
# address         object
# name            object
# online_order    object
# book_table      object
# rate            object
# votes           object
# phone           object
# location        object
# rest_type       object
# dish_liked      object
# cuisines        object
# Cost            object
# reviews_list    object
# menu_item       object
# type            object
# city            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# url              4567
# address          4538
# name             4537
# online_order     4539
# book_table       4579
# rate            12359
# votes            4599
# phone            5818
# location         4645
# rest_type        4859
# dish_liked      32724
# cuisines         4724
# Cost             5028
# reviews_list     4710
# menu_item        9089
# type             9118
# city             9147
# dtype: int64

# %%
#Drop dublicate value
df.drop_duplicates(inplace=True,keep='first')

# %%
#data cleaning and changing
# changing online order (yes / no) in 1 & 0
df['online_order']=df['online_order'].apply(lambda x: '1' if str(x)=='Yes' else '0')

# changing book table (yes / no) in 1 & 0
df['book_table']=df['book_table'].apply(lambda x: '1' if str(x)=='Yes' else '0')

# %%
#showing data after cleaning and changing
df.head(3)
# Out:
#                                                  url  ...          city
# 0  https://www.zomato.com/bangalore/jalsa-banasha...  ...  Banashankari
# 1  https://www.zomato.com/bangalore/spice-elephan...  ...  Banashankari
# 2  https://www.zomato.com/SanchurroBangalore?cont...  ...  Banashankari
#
# [3 rows x 17 columns]

# %%
# changing and replacing in rate
df['rate']=df['rate'].apply(lambda x: str(x).split('/')[0])

# %%
df.head()
# Out:
#                                                  url  ...          city
# 0  https://www.zomato.com/bangalore/jalsa-banasha...  ...  Banashankari
# 1  https://www.zomato.com/bangalore/spice-elephan...  ...  Banashankari
# 2  https://www.zomato.com/SanchurroBangalore?cont...  ...  Banashankari
# 3  https://www.zomato.com/bangalore/addhuri-udupi...  ...  Banashankari
# 4  https://www.zomato.com/bangalore/grand-village...  ...  Banashankari
#
# [5 rows x 17 columns]

# %%
df.head()
# Out:
#                                                  url  ...          city
# 0  https://www.zomato.com/bangalore/jalsa-banasha...  ...  Banashankari
# 1  https://www.zomato.com/bangalore/spice-elephan...  ...  Banashankari
# 2  https://www.zomato.com/SanchurroBangalore?cont...  ...  Banashankari
# 3  https://www.zomato.com/bangalore/addhuri-udupi...  ...  Banashankari
# 4  https://www.zomato.com/bangalore/grand-village...  ...  Banashankari
#
# [5 rows x 17 columns]

# %%
#Location of the restaurant
chains=df['name'].value_counts()[0:10]
sns.barplot(x=chains,y=chains.index,palette='deep')
plt.title("Most famous restaurants chains in Bangalore")
plt.xlabel("Number of outlets")
plt.ylabel("Chains")
# Out:
# Text(0, 0.5, 'Chains')

# %%
#Number of resturent in area wise
plt.figure(figsize=(15,15))
loc=df['location'].value_counts()[0:10]
sns.barplot(x=loc,y=loc.index,palette='deep')

# %%
# online order facility
labels = ['Yes','No']
colors = ['#66b3ff','#99ff99']
explode = (0.05,0.05)

plt.figure(figsize=(8,8))
plt.pie(df['online_order'].value_counts(),colors = colors,autopct='%1.1f%%',labels=labels,startangle=90, pctdistance=0.85, explode = explode)

#draw circle

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle) 
plt.tight_layout() 
plt.title("Restaurants with Online Order Facilty")
plt.show()

# %%
#Restaurant types in city
x=df['rest_type'].value_counts()[0:15]
sns.barplot(x,x.index)
plt.title("Restaurant types")
plt.xlabel("Number of restaurants")
plt.ylabel('Types')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0, 0.5, 'Types')
